# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## TCS Antibiotic Resistance

# %%
data = pd.read_csv("../../heatmap/TCS_summary_UPDATED_Antibiotic.csv", index_col=0)
data=data.drop('Function', axis=1)
data.head()
# Out:
#                                 E. faecium  S. aureus  K. pneumoniae  \
# TCSs for Antibiotic Resistance
# GraSR                                 1.84      99.91            NaN
# NsaSR                                  NaN      72.56            NaN
# VraSR                               100.00      99.31            NaN
# VanSR                                62.47       0.09            NaN
# CpxAR                                  NaN        NaN          99.82
#
#                                 A. baumannii  P. aeruginosa  E. cloacae  \
# TCSs for Antibiotic Resistance
# GraSR                                    NaN            NaN         NaN
# NsaSR                                    NaN            NaN         NaN
# VraSR                                    NaN            NaN         NaN
# VanSR                                    NaN            NaN         NaN
# CpxAR                                    NaN           0.65       46.36
#
#                                 E. coli
# ...

# %%
sns.set(font_scale=1.4)
ax=sns.heatmap(data,linewidths=0.01,linecolor="k",  cmap="YlGnBu")

# %% [markdown]
# ## Virulence TCS

# %%
data = pd.read_csv("../heatmap/TCS_summary_UPDATED_Virulence.csv", index_col=0)
data.head()
# Out:
#                      E. faecium  S. aureus  K. pneumoniae  A. baumannii  \
# TCSs for Virulence
# AgrCA                     30.71      99.91            NaN           NaN
# AlgZR                       NaN        NaN            NaN         97.66
# BvgSA                       NaN        NaN            NaN           NaN
# SaeSR                       NaN     100.00            NaN           NaN
# SrrBA                       NaN      99.91            NaN           NaN
#
#                      P. aeruginosa  E. cloacae  E. coli   Function
# TCSs for Virulence
# AgrCA                          NaN         NaN      NaN  Virulence
# AlgZR                        99.57         NaN      NaN  Virulence
# BvgSA                          NaN        4.55      NaN  Virulence
# SaeSR                          NaN         NaN      NaN  Virulence
# SrrBA                          NaN         NaN      NaN  Virulence

# %%
data=data.drop('Function', axis=1)
data.head()
# Out:
#                      E. faecium  S. aureus  K. pneumoniae  A. baumannii  \
# TCSs for Virulence
# AgrCA                     30.71      99.91            NaN           NaN
# AlgZR                       NaN        NaN            NaN         97.66
# BvgSA                       NaN        NaN            NaN           NaN
# SaeSR                       NaN     100.00            NaN           NaN
# SrrBA                       NaN      99.91            NaN           NaN
#
#                      P. aeruginosa  E. cloacae  E. coli
# TCSs for Virulence
# AgrCA                          NaN         NaN      NaN
# AlgZR                        99.57         NaN      NaN
# BvgSA                          NaN        4.55      NaN
# SaeSR                          NaN         NaN      NaN
# SrrBA                          NaN         NaN      NaN

# %%
sns.set(font_scale=1.4)
ax=sns.heatmap(data,linewidths=0.01,linecolor="k", cmap="Spectral")

# %% [markdown]
# ## Other TCS

# %%
data = pd.read_csv("../../heatmap/TCS_summary_UPDATED_Others.csv", index_col=0)
data=data.drop('Function', axis=1)
data.head()
# Out:
#                                E. faecium  S. aureus  K. pneumoniae  \
# Two-component system (Others)
# CusSR                                 NaN        NaN          99.65
# CreCB                                 NaN        NaN          99.74
# YedVW                                 NaN        NaN            NaN
# PfeSR                                 NaN        NaN            NaN
# AtoSC                                 NaN        NaN           6.49
#
#                                A. baumannii  P. aeruginosa  E. cloacae  \
# Two-component system (Others)
# CusSR                                 52.16            NaN       59.39
# CreCB                                  5.40          99.68         NaN
# YedVW                                   NaN            NaN         NaN
# PfeSR                                   NaN          99.35         NaN
# AtoSC                                   NaN            NaN         NaN
#
#                                E. coli
# ...

# %%
#sns.set(font_scale=1.4)
plt.figure(figsize=(10,12))
ax=sns.heatmap(data,linewidths=0.01, linecolor="k",  cmap="RdYlBu")

# %% [markdown]
# ## Predicted TCS

# %%
data = pd.read_csv("../../heatmap/TCS_summary_UPDATED_Predicted.csv", index_col=0)
data=data.drop('Function', axis=1)
data.head()
# Out:
#                                   E. faecium  S. aureus  K. pneumoniae  \
# Two-component system (Predicted)
# LuxR_HK_RR                             84.51        NaN          61.52
# ABC_HK_RR                              98.16        NaN            NaN
# AraC_HK_RR                               NaN      100.0           0.35
# Asn_HK_RR                                NaN        NaN            NaN
# Meta_HK_RR                               NaN        NaN            NaN
#
#                                   A. baumannii  P. aeruginosa  E. cloacae  \
# Two-component system (Predicted)
# LuxR_HK_RR                               95.50         100.00       81.52
# ABC_HK_RR                                  NaN          14.10         NaN
# AraC_HK_RR                                 NaN          99.78         NaN
# Asn_HK_RR                                53.60            NaN         NaN
# Meta_HK_RR                               32.01            NaN         NaN
#
# ...

# %%
ax=sns.heatmap(data,linewidths=0.01,linecolor="k",  cmap="terrain_r")
